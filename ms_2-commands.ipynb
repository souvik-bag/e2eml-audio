# %% [markdown]
# ### create docker image
#
# docker build -t audio-sentiment -f docker/Dockerfile .

# %% [markdown]
# ### run the containers
#
# docker run -d -p 8000:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_distilbert-base-uncased-finetuned-sst-2-english_int8.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
# [1.244, 5.517, 2.865, 1.322, 0.788]
# 2.3472
# [1.269, 5.900, 3.088, 1.318, 1.227]
# 2.5604
#
#
# docker run -d -p 8001:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_distilbert-base-uncased-finetuned-sst-2-english_fp16.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
#
# docker run -d -p 8002:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_distilbert-base-uncased-finetuned-sst-2-english_fp32.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
# [15.585, 1.303, 2.987, 6.305, 1.112]
# 5.4584
#
#
#
#
#
# docker run -d -p 8010:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_cardiffnlp_twitter-roberta-base-sentiment-latest_int8.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
# [1.136, 5.518, 2.779, 1.226, 13.905]
# 4.9128
#
# docker run -d -p 8011:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_cardiffnlp_twitter-roberta-base-sentiment-latest_fp16.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
#
# docker run -d -p 8012:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_cardiffnlp_twitter-roberta-base-sentiment-latest_fp32.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
# [1.172, 5.870, 2.806, 1.231, 14.125]
# 5.0408
#
#
#
#
#
#
# docker run -d -p 8020:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_siebert_sentiment-roberta-large-english_int8.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
# [1.194, 5.954, 2.975, 1.285, 14.150]
# 5.1116
#
# docker run -d -p 8021:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_siebert_sentiment-roberta-large-english_fp16.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
#
# docker run -d -p 8022:8000 `
#   -e A2T_MODEL_PATH="/models/a2t_AventIQ-AI_whisper-audio-to-text_fp32" `
#   -e T2S_MODEL_PATH="/models/t2s_siebert_sentiment-roberta-large-english_fp32.onnx" `
#   -v "${PWD}\app:/app" `
#   -v "${PWD}\models:/models" `
#   audio-sentiment
#
# [1.256, 7.067, 3.255, 1.385, 13.216]
# 5.2358

# %% [markdown]
# ### test inputing audio file
#
# Measure-Command {
#     $FilePath = "D:\Mizzou\25fall\eeml\project\e2eml-audio\data\audios\audio_00000.wav"
#     $FileContent = [System.IO.File]::ReadAllBytes($FilePath)
#     $FileName = [System.IO.Path]::GetFileName($FilePath)
#
#     $boundary = "----WebKitFormBoundary$([System.Guid]::NewGuid().ToString())"
#
#     $bodyLines = @(
#         "--$boundary",
#         "Content-Disposition: form-data; name=`"audio`"; filename=`"$FileName`"",
#         "Content-Type: audio/wav",
#         "",
#         [System.Text.Encoding]::UTF8.GetString($FileContent),
#         "--$boundary--"
#     ) -join "`r`n"
#
#     Invoke-RestMethod -Uri "http://localhost:8002/predict" `
#       -Method POST `
#       -ContentType "multipart/form-data; boundary=$boundary" `
#       -Body $bodyLines
# }

# %%
$FilePath = "D:\Mizzou\25fall\eeml\project\e2eml-audio\data\audios\audio_00000.wav"
$FileContent = [System.IO.File]::ReadAllBytes($FilePath)
$FileName = [System.IO.Path]::GetFileName($FilePath)

$boundary = "----WebKitFormBoundary$([System.Guid]::NewGuid().ToString())"

$bodyLines = @(
    "--$boundary",
    "Content-Disposition: form-data; name=`"audio`"; filename=`"$FileName`"",
    "Content-Type: audio/wav",
    "",
    [System.Text.Encoding]::UTF8.GetString($FileContent),
    "--$boundary--"
) -join "`r`n"

Invoke-RestMethod -Uri "http://localhost:8002/predict" `
    -Method POST `
    -ContentType "multipart/form-data; boundary=$boundary" `
    -Body $bodyLines

# %% [markdown]
# Measure-Command {
#     $FilePath = "D:\Mizzou\25fall\eeml\project\e2eml-audio\data\audios\audio_00000.wav"
#     $FileContent = [System.IO.File]::ReadAllBytes($FilePath)
#     $FileName = [System.IO.Path]::GetFileName($FilePath)
#
#     $boundary = "----WebKitFormBoundary$([System.Guid]::NewGuid().ToString())"
#
#     $bodyLines = @(
#         "--$boundary",
#         "Content-Disposition: form-data; name=`"audio`"; filename=`"$FileName`"",
#         "Content-Type: audio/wav",
#         "",
#         [System.Text.Encoding]::UTF8.GetString($FileContent),
#         "--$boundary--"
#     ) -join "`r`n"
#
#     Invoke-RestMethod -Uri "http://localhost:8000/predict" `
#       -Method POST `
#       -ContentType "multipart/form-data; boundary=$boundary" `
#       -Body $bodyLines
# }
#
#
# Measure-Command {
#     $FilePath = "D:\Mizzou\25fall\eeml\project\e2eml-audio\data\audios\audio_00001.wav"
#     $FileContent = [System.IO.File]::ReadAllBytes($FilePath)
#     $FileName = [System.IO.Path]::GetFileName($FilePath)
#
#     $boundary = "----WebKitFormBoundary$([System.Guid]::NewGuid().ToString())"
#
#     $bodyLines = @(
#         "--$boundary",
#         "Content-Disposition: form-data; name=`"audio`"; filename=`"$FileName`"",
#         "Content-Type: audio/wav",
#         "",
#         [System.Text.Encoding]::UTF8.GetString($FileContent),
#         "--$boundary--"
#     ) -join "`r`n"
#
#     Invoke-RestMethod -Uri "http://localhost:8000/predict" `
#       -Method POST `
#       -ContentType "multipart/form-data; boundary=$boundary" `
#       -Body $bodyLines
# }
#
#
# Measure-Command {
#     $FilePath = "D:\Mizzou\25fall\eeml\project\e2eml-audio\data\audios\audio_00002.wav"
#     $FileContent = [System.IO.File]::ReadAllBytes($FilePath)
#     $FileName = [System.IO.Path]::GetFileName($FilePath)
#
#     $boundary = "----WebKitFormBoundary$([System.Guid]::NewGuid().ToString())"
#
#     $bodyLines = @(
#         "--$boundary",
#         "Content-Disposition: form-data; name=`"audio`"; filename=`"$FileName`"",
#         "Content-Type: audio/wav",
#         "",
#         [System.Text.Encoding]::UTF8.GetString($FileContent),
#         "--$boundary--"
#     ) -join "`r`n"
#
#     Invoke-RestMethod -Uri "http://localhost:8000/predict" `
#       -Method POST `
#       -ContentType "multipart/form-data; boundary=$boundary" `
#       -Body $bodyLines
# }
#
#
# Measure-Command {
#     $FilePath = "D:\Mizzou\25fall\eeml\project\e2eml-audio\data\audios\audio_00003.wav"
#     $FileContent = [System.IO.File]::ReadAllBytes($FilePath)
#     $FileName = [System.IO.Path]::GetFileName($FilePath)
#
#     $boundary = "----WebKitFormBoundary$([System.Guid]::NewGuid().ToString())"
#
#     $bodyLines = @(
#         "--$boundary",
#         "Content-Disposition: form-data; name=`"audio`"; filename=`"$FileName`"",
#         "Content-Type: audio/wav",
#         "",
#         [System.Text.Encoding]::UTF8.GetString($FileContent),
#         "--$boundary--"
#     ) -join "`r`n"
#
#     Invoke-RestMethod -Uri "http://localhost:8000/predict" `
#       -Method POST `
#       -ContentType "multipart/form-data; boundary=$boundary" `
#       -Body $bodyLines
# }
#
#
# Measure-Command {
#     $FilePath = "D:\Mizzou\25fall\eeml\project\e2eml-audio\data\audios\audio_00004.wav"
#     $FileContent = [System.IO.File]::ReadAllBytes($FilePath)
#     $FileName = [System.IO.Path]::GetFileName($FilePath)
#
#     $boundary = "----WebKitFormBoundary$([System.Guid]::NewGuid().ToString())"
#
#     $bodyLines = @(
#         "--$boundary",
#         "Content-Disposition: form-data; name=`"audio`"; filename=`"$FileName`"",
#         "Content-Type: audio/wav",
#         "",
#         [System.Text.Encoding]::UTF8.GetString($FileContent),
#         "--$boundary--"
#     ) -join "`r`n"
#
#     Invoke-RestMethod -Uri "http://localhost:8000/predict" `
#       -Method POST `
#       -ContentType "multipart/form-data; boundary=$boundary" `
#       -Body $bodyLines
# }
